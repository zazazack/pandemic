# %%
import pandas as pd

# %%
df = pd.read_csv("csse_covid_19_daily_reports.csv.gz", index_col=0)

# %%
df
# Out:
#              Last Update  Country/Region  \
# 0    2020-02-26 14:13:10  Mainland China
# 1    2020-02-26 10:33:02  Mainland China
# 2    2020-02-26 10:33:02  Mainland China
# 3    2020-02-26 11:03:11     South Korea
# 4    2020-02-26 10:33:02  Mainland China
# ..                   ...             ...
# 250  2020-03-06 04:33:03       Australia
# 251  2020-02-24 23:33:02              US
# 252  2020-03-07 19:53:02              US
# 253  2020-02-24 23:33:02              US
# 254  2020-02-24 23:33:02              US
#
#                            Province/State  Latitude  Longitude  Confirmed  \
# 0                                   Hubei       NaN        NaN    65187.0
# 1                               Guangdong       NaN        NaN     1347.0
# 2                                   Henan       NaN        NaN     1271.0
# 3                                     NaN       NaN        NaN     1261.0
# 4                                Zhejiang       NaN        NaN     1205.0
# ...

# %%
df['Country/Region'] = df['Country/Region'].replace("US", 'United States of America')
df['Country/Region'] = df['Country/Region'].replace("Mainland China", 'China')

# %%
df.head()
# Out:
#            Last Update Country/Region Province/State  Latitude  Longitude  \
# 0  2020-02-26 14:13:10          China          Hubei       NaN        NaN
# 1  2020-02-26 10:33:02          China      Guangdong       NaN        NaN
# 2  2020-02-26 10:33:02          China          Henan       NaN        NaN
# 3  2020-02-26 11:03:11    South Korea            NaN       NaN        NaN
# 4  2020-02-26 10:33:02          China       Zhejiang       NaN        NaN
#
#    Confirmed  Recovered  Deaths  \
# 0    65187.0    20969.0  2615.0
# 1     1347.0      851.0     7.0
# 2     1271.0     1033.0    19.0
# 3     1261.0       22.0    12.0
# 4     1205.0      867.0     1.0
#
#                                           input_file
# 0  data/COVID-19/csse_covid_19_data/csse_covid_19...
# 1  data/COVID-19/csse_covid_19_data/csse_covid_19...
# 2  data/COVID-19/csse_covid_19_data/csse_covid_19...
# 3  data/COVID-19/csse_covid_19_data/csse_covid_19...
# 4  data/COVID-19/csse_covid_19_data/csse_covid_19...

# %%
df['Active'] = df['Confirmed'] - df['Recovered']

# %%
df.index = pd.DatetimeIndex(df['Last Update'])

# %%
df.plot()

# %%
df.to_csv('./enriched.csv')

# %%
df.agg('sum')
# Out:
# Last Update       2020-02-26 14:13:102020-02-26 10:33:022020-02-...
# Country/Region    ChinaChinaChinaSouth KoreaChinaChinaChinaChina...
# Latitude                                                    87623.6
# Longitude                                                   21804.8
# Confirmed                                               3.28016e+06
# Recovered                                               1.20319e+06
# Deaths                                                       103267
# input_file        data/COVID-19/csse_covid_19_data/csse_covid_19...
# Active                                                  2.07128e+06
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5632 entries, 2020-02-26 14:13:10 to 2020-02-24 23:33:02
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Last Update     5632 non-null   object
#  1   Country/Region  5632 non-null   object
#  2   Province/State  3456 non-null   object
#  3   Latitude        2814 non-null   float64
#  4   Longitude       2814 non-null   float64
#  5   Confirmed       5613 non-null   float64
#  6   Recovered       5244 non-null   float64
#  7   Deaths          5191 non-null   float64
#  8   input_file      5632 non-null   object
#  9   Active          5244 non-null   float64
# dtypes: float64(6), object(4)
# memory usage: 484.0+ KB

# %%
df['Last Update'] = pd.to_datetime(df['Last Update'])

# %%
df
# Out:
#                             Last Update            Country/Region  \
# Last Update
# 2020-02-26 14:13:10 2020-02-26 14:13:10                     China
# 2020-02-26 10:33:02 2020-02-26 10:33:02                     China
# 2020-02-26 10:33:02 2020-02-26 10:33:02                     China
# 2020-02-26 11:03:11 2020-02-26 11:03:11               South Korea
# 2020-02-26 10:33:02 2020-02-26 10:33:02                     China
# ...                                 ...                       ...
# 2020-03-06 04:33:03 2020-03-06 04:33:03                 Australia
# 2020-02-24 23:33:02 2020-02-24 23:33:02  United States of America
# 2020-03-07 19:53:02 2020-03-07 19:53:02  United States of America
# 2020-02-24 23:33:02 2020-02-24 23:33:02  United States of America
# 2020-02-24 23:33:02 2020-02-24 23:33:02  United States of America
#
#                                            Province/State  Latitude  \
# Last Update
# 2020-02-26 14:13:10                                 Hubei       NaN
# ...
