# %%
import pandas as pd

# %%
df = pd.read_csv("csse_covid_19_daily_reports.csv.gz", index_col=0)

# %%
df
# Out:
#      Confirmed  Country/Region  Deaths          Last Update  Latitude  \
# 0      65187.0  Mainland China  2615.0  2020-02-26 14:13:10       NaN
# 1       1347.0  Mainland China     7.0  2020-02-26 10:33:02       NaN
# 2       1271.0  Mainland China    19.0  2020-02-26 10:33:02       NaN
# 3       1261.0     South Korea    12.0  2020-02-26 11:03:11       NaN
# 4       1205.0  Mainland China     1.0  2020-02-26 10:33:02       NaN
# ..         ...             ...     ...                  ...       ...
# 250        0.0       Australia     0.0  2020-03-06 04:33:03  -12.4634
# 251        0.0              US     0.0  2020-02-24 23:33:02   29.3829
# 252        0.0              US     0.0  2020-03-07 19:53:02   30.3213
# 253        0.0              US     0.0  2020-02-24 23:33:02   41.2545
# 254        0.0              US     0.0  2020-02-24 23:33:02   38.2721
#
#      Longitude                        Province/State  Recovered  \
# 0          NaN                                 Hubei    20969.0
# 1          NaN                             Guangdong      851.0
# 2          NaN                                 Henan     1033.0
# 3          NaN                                   NaN       22.0
# 4          NaN                              Zhejiang      867.0
# ..         ...                                   ...        ...
# 250   130.8456                    Northern Territory        0.0
# 251   -98.6134  Lackland, TX (From Diamond Princess)        0.0
# 252   -95.4778                 Montgomery County, TX        0.0
# 253   -95.9758     Omaha, NE (From Diamond Princess)        0.0
# 254  -121.9399    Travis, CA (From Diamond Princess)        0.0
#
#                                             input_file
# 0    COVID-19/csse_covid_19_data/csse_covid_19_dail...
# 1    COVID-19/csse_covid_19_data/csse_covid_19_dail...
# 2    COVID-19/csse_covid_19_data/csse_covid_19_dail...
# 3    COVID-19/csse_covid_19_data/csse_covid_19_dail...
# 4    COVID-19/csse_covid_19_data/csse_covid_19_dail...
# ..                                                 ...
# 250  COVID-19/csse_covid_19_data/csse_covid_19_dail...
# 251  COVID-19/csse_covid_19_data/csse_covid_19_dail...
# 252  COVID-19/csse_covid_19_data/csse_covid_19_dail...
# 253  COVID-19/csse_covid_19_data/csse_covid_19_dail...
# 254  COVID-19/csse_covid_19_data/csse_covid_19_dail...
#
# [5153 rows x 9 columns]

# %%
df['Country/Region'] = df['Country/Region'].replace("US", 'United States of America')
df['Country/Region'] = df['Country/Region'].replace("Mainland China", 'China')

# %%
df.head()
# Out:
#    Confirmed Country/Region  Deaths          Last Update  Latitude  Longitude  \
# 0    65187.0          China  2615.0  2020-02-26 14:13:10       NaN        NaN
# 1     1347.0          China     7.0  2020-02-26 10:33:02       NaN        NaN
# 2     1271.0          China    19.0  2020-02-26 10:33:02       NaN        NaN
# 3     1261.0    South Korea    12.0  2020-02-26 11:03:11       NaN        NaN
# 4     1205.0          China     1.0  2020-02-26 10:33:02       NaN        NaN
#
#   Province/State  Recovered                                         input_file
# 0          Hubei    20969.0  COVID-19/csse_covid_19_data/csse_covid_19_dail...
# 1      Guangdong      851.0  COVID-19/csse_covid_19_data/csse_covid_19_dail...
# 2          Henan     1033.0  COVID-19/csse_covid_19_data/csse_covid_19_dail...
# 3            NaN       22.0  COVID-19/csse_covid_19_data/csse_covid_19_dail...
# 4       Zhejiang      867.0  COVID-19/csse_covid_19_data/csse_covid_19_dail...

# %%
df['Active'] = df['Confirmed'] - df['Recovered']

# %%
df.index = pd.DatetimeIndex(df['Last Update'])

# %%
df.plot()

# %%
df.to_csv('./enriched.csv')
